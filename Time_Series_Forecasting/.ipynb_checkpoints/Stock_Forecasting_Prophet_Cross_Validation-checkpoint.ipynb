# %% [markdown]
# # Stock Forecasting using Prophet (Cross Validation)

# %% [markdown]
# https://facebook.github.io/prophet/

# %%
# Libraries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from prophet import Prophet
from prophet.diagnostics import cross_validation
from prophet.diagnostics import performance_metrics
from prophet.plot import plot_cross_validation_metric

import warnings
warnings.filterwarnings("ignore")

import yfinance as yf
yf.pdr_override()

# %%
stock = 'TSLA' # input
start = '2012-01-01' # input 
end = '2022-04-29'  # input
df = yf.download(stock, start, end)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
plt.figure(figsize=(16,8))
plt.plot(df['Adj Close'])
plt.title('Stock Price')
plt.ylabel('Price')
plt.show()

# %%
df = df.reset_index()
df = df.rename(columns={'Date': 'ds', 'Close': 'y'})
df
# Out:
#              ds         Open         High         Low            y  \
# 0    2012-01-03     5.788000     5.900000    5.530000     5.616000
# 1    2012-01-04     5.642000     5.734000    5.500000     5.542000
# 2    2012-01-05     5.552000     5.586000    5.370000     5.424000
# 3    2012-01-06     5.440000     5.558000    5.282000     5.382000
# 4    2012-01-09     5.400000     5.498000    5.224000     5.450000
# ...         ...          ...          ...         ...          ...
# 2593 2022-04-22  1014.909973  1034.849976  994.000000  1005.049988
# 2594 2022-04-25   978.969971  1008.619995  975.299988   998.020020
# 2595 2022-04-26   995.429993  1000.000000  875.000000   876.419983
# 2596 2022-04-27   898.580017   918.000000  877.359985   881.510010
# 2597 2022-04-28   899.979980   899.469971  821.700012   877.510010
#
#         Adj Close    Volume
# 0        5.616000   4640500
# 1        5.542000   3150500
# 2        5.424000   5027500
# 3        5.382000   4931500
# ...

# %%
df = df[['ds', 'y']]
df
# Out:
#              ds            y
# 0    2012-01-03     5.616000
# 1    2012-01-04     5.542000
# 2    2012-01-05     5.424000
# 3    2012-01-06     5.382000
# 4    2012-01-09     5.450000
# ...         ...          ...
# 2593 2022-04-22  1005.049988
# 2594 2022-04-25   998.020020
# 2595 2022-04-26   876.419983
# 2596 2022-04-27   881.510010
# 2597 2022-04-28   877.510010
#
# [2598 rows x 2 columns]

# %%
m = Prophet()
m.fit(df)
# Out:
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# Initial log joint probability = -103.34
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       99       6707.14    0.00847308       519.145           1           1      114
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      199       6749.39    0.00792865       785.225           1           1      227
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      299       6758.23    0.00128635       148.815      0.5195      0.7649      350
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      341       6762.43   0.000205038       211.248   2.191e-07       0.001      440  LS failed, Hessian reset
#      399       6770.46   0.000743311       384.631           1           1      510
# ...

# %%
df_cv = cross_validation(m, initial='2598 days', period='180 days', horizon = '365 days')
# Out:
# INFO:prophet:Making 5 forecasts with cutoffs between 2019-05-09 00:00:00 and 2021-04-28 00:00:00
#   0%|          | 0/5 [00:00<?, ?it/s]
# Initial log joint probability = -54.6593
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       99       4048.63     0.0378276       1168.12           1           1      115
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      199       4136.79    0.00750165       116.622           1           1      229
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      299       4171.89     0.0352376       666.839           1           1      347
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      399       4188.99   0.000736939       332.283      0.2553      0.2553      478
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
# ...

# %%
df_cv.tail()
# Out:
#              ds         yhat  yhat_lower   yhat_upper            y     cutoff
# 1255 2022-04-22  1061.652563  982.502499  1143.361355  1005.049988 2021-04-28
# 1256 2022-04-25  1065.257970  983.356352  1138.264191   998.020020 2021-04-28
# 1257 2022-04-26  1066.108694  984.525084  1142.663864   876.419983 2021-04-28
# 1258 2022-04-27  1067.151884  988.626144  1143.404370   881.510010 2021-04-28
# 1259 2022-04-28  1067.131383  989.634544  1142.534575   877.510010 2021-04-28

# %%
cutoffs = pd.to_datetime(['2019-05-09', '2021-04-28'])
df_cv2 = cross_validation(m, cutoffs=cutoffs, horizon='365 days')
# Out:
#   0%|          | 0/2 [00:00<?, ?it/s]
# Initial log joint probability = -54.6593
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       99       4048.63     0.0378276       1168.12           1           1      115
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      199       4136.79    0.00750165       116.622           1           1      229
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      299       4171.89     0.0352376       666.839           1           1      347
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      399       4188.99   0.000736939       332.283      0.2553      0.2553      478
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
# ...

# %%
df_p = performance_metrics(df_cv)
df_p.head()
# Out:
#   horizon           mse        rmse        mae      mape     mdape     smape  \
# 0 37 days  10336.909649  101.670594  73.684627  0.337916  0.350261  0.374706
# 1 38 days  11299.825511  106.300637  76.900321  0.344211  0.357195  0.383945
# 2 39 days  12268.474995  110.763148  79.642909  0.349683  0.363295  0.390670
# 3 40 days  12960.869608  113.845815  81.742998  0.351863  0.366499  0.392932
# 4 41 days  13694.687764  117.024304  83.672072  0.354718  0.368364  0.396210
#
#    coverage
# 0  0.061508
# 1  0.055556
# 2  0.047619
# 3  0.047619
# 4  0.043651

# %%
fig = plot_cross_validation_metric(df_cv, metric='mape')
